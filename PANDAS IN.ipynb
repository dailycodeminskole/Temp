# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Intro to Pandas

# %%
#  reading data from source

# %%
df = pd.read_csv(r"C:/Users/RAHUL/Documents/OnePython/0.SelfStudy/players_15.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df #limited data will be displayed
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15461     225509  https://sofifa.com/player/225509/aaron-collins...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# ...

# %%
# view first few records
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
#    height_cm  weight_kg  nationality                 club  ...   lwb   ldm  \
# ...

# %%
df.head(10)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 5     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 6     183277  https://sofifa.com/player/183277/eden-hazard/1...
# 7       7826  https://sofifa.com/player/7826/robin-van-persi...
# 8     121944  https://sofifa.com/player/121944/bastian-schwe...
# 9     156616  https://sofifa.com/player/156616/franck-ribery...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# ...

# %%
df.tail()
# Out:
#        sofifa_id                                         player_url  \
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15461     225509  https://sofifa.com/player/225509/aaron-collins...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#        short_name      long_name  age         dob  height_cm  weight_kg  \
# 15460   E. Redman   Ellis Redman   17  1996-09-26        187         81
# 15461  A. Collins  Aaron Collins   17  1997-06-01        178         57
# 15462    P. Żemło    Piotr Żemło   18  1995-07-10        190         76
# 15463   T. Davies     Tom Davies   22  1992-04-18        180         70
# 15464  P. Tisdale   Paul Tisdale   41  1973-01-14        175         72
#
#       nationality            club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
df.tail(10)
# Out:
#        sofifa_id                                         player_url  \
# 15455      11728  https://sofifa.com/player/11728/barry-richards...
# 15456     211228  https://sofifa.com/player/211228/matthew-palme...
# 15457     220939  https://sofifa.com/player/220939/luke-pilling/...
# 15458     222997  https://sofifa.com/player/222997/marcus-maier/...
# 15459     214725  https://sofifa.com/player/214725/sam-ramsbotto...
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15461     225509  https://sofifa.com/player/225509/aaron-collins...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#           short_name         long_name  age         dob  height_cm  weight_kg  \
# 15455  B. Richardson  Barry Richardson   44  1969-08-05        185         77
# ...

# %%
# stroring the data to another csv
df_top10 = df.head(10)
df_top10.to_csv("players_top10.csv")

# %%
pwd
# Out:
# 'C:\\Users\\RAHUL\\Documents\\OnePython\\0.SelfStudy'

# %% [markdown]
# # Exploring read_csv parameters

# %%
pd.read_csv("players_top10.csv") # we got an extra column ??? how to avaoid this ??
# Out:
#    Unnamed: 0  sofifa_id                                         player_url  \
# 0           0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1           1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3           3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4           4     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 5           5     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 6           6     183277  https://sofifa.com/player/183277/eden-hazard/1...
# 7           7       7826  https://sofifa.com/player/7826/robin-van-persi...
# 8           8     121944  https://sofifa.com/player/121944/bastian-schwe...
# 9           9     156616  https://sofifa.com/player/156616/franck-ribery...
#
#           short_name                            long_name  age         dob  \
# ...

# %%
# using other delimiter
pd.read_csv("players_top10.csv",sep='&')
# Out:
#                ,sofifa_id,player_url,short_name,long_name,age,dob,height_cm,weight_kg,nationality,club,overall,potential,value_eur,wage_eur,player_positions,preferred_foot,international_reputation,weak_foot,skill_moves,work_rate,body_type,real_face,release_clause_eur,player_tags,team_position,team_jersey_number,loaned_from,joined,contract_valid_until,nation_position,nation_jersey_number,pace,shooting,passing,dribbling,defending,physic,gk_diving,gk_handling,gk_kicking,gk_reflexes,gk_speed,gk_positioning,player_traits,attacking_crossing,attacking_finishing,attacking_heading_accuracy,attacking_short_passing,attacking_volleys,skill_dribbling,skill_curve,skill_fk_accuracy,skill_long_passing,skill_ball_control,movement_acceleration,movement_sprint_speed,movement_agility,movement_reactions,movement_balance,power_shot_power,power_jumping,power_stamina,power_strength,power_long_shots,mentality_aggression,mentality_interceptions,mentality_positioning,mentality_vision,mentality_penalties,mental
# ...

# %%
# Avoiding header
df_top10 = df.head(10)
df_top10.to_csv("players_top10.csv")

# %%
df_top10
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 5     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 6     183277  https://sofifa.com/player/183277/eden-hazard/1...
# 7       7826  https://sofifa.com/player/7826/robin-van-persi...
# 8     121944  https://sofifa.com/player/121944/bastian-schwe...
# 9     156616  https://sofifa.com/player/156616/franck-ribery...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# ...

# %%
df = pd.read_csv('players_top10.csv',header=None)

# %%
df
# Out:
#     0          1                                                  2    \
# 0   NaN  sofifa_id                                         player_url
# 1   0.0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2   1.0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3   2.0       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 4   3.0      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 5   4.0     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 6   5.0     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 7   6.0     183277  https://sofifa.com/player/183277/eden-hazard/1...
# 8   7.0       7826  https://sofifa.com/player/7826/robin-van-persi...
# 9   8.0     121944  https://sofifa.com/player/121944/bastian-schwe...
# 10  9.0     156616  https://sofifa.com/player/156616/franck-ribery...
#
#                   3                                    4    5           6    \
# ...

# %%
df = pd.read_csv('players_top10.csv',header=None,skiprows=[0 ,1,2,7])

# %%
df
# Out:
#    0       1                                                  2    \
# 0    2    9014  https://sofifa.com/player/9014/arjen-robben/15...
# 1    3   41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 2    4  167495  https://sofifa.com/player/167495/manuel-neuer/...
# 3    5  176580  https://sofifa.com/player/176580/luis-suarez/1...
# 4    7    7826  https://sofifa.com/player/7826/robin-van-persi...
# 5    8  121944  https://sofifa.com/player/121944/bastian-schwe...
# 6    9  156616  https://sofifa.com/player/156616/franck-ribery...
#
#                  3                         4    5           6    7    8    \
# 0          A. Robben              Arjen Robben   30  1984-01-23  180   80
# 1     Z. Ibrahimović        Zlatan Ibrahimović   32  1981-10-03  195   95
# 2           M. Neuer              Manuel Neuer   28  1986-03-27  193   92
# 3          L. Suárez  Luis Alberto Suárez Díaz   27  1987-01-24  181   81
# ...

# %%
df = pd.read_csv('players_top10.csv',header=None,na_values=80) # convert 80 to NaN value

# %%
df
# Out:
#     0          1                                                  2    \
# 0   NaN  sofifa_id                                         player_url
# 1   0.0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 2   1.0      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3   2.0       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 4   3.0      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 5   4.0     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 6   5.0     176580  https://sofifa.com/player/176580/luis-suarez/1...
# 7   6.0     183277  https://sofifa.com/player/183277/eden-hazard/1...
# 8   7.0       7826  https://sofifa.com/player/7826/robin-van-persi...
# 9   8.0     121944  https://sofifa.com/player/121944/bastian-schwe...
# 10  9.0     156616  https://sofifa.com/player/156616/franck-ribery...
#
#                   3                                    4    5           6    \
# ...

# %%
# Replacing the original file as old is corrupted

# %%
df = pd.read_csv(r"C:/Users/RAHUL/Documents/OnePython/0.SelfStudy/players_15.csv")

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3          41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4         167495  https://sofifa.com/player/167495/manuel-neuer/...
# ...          ...                                                ...
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15461     225509  https://sofifa.com/player/225509/aaron-collins...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   27
# ...

# %%
df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg       overall  \
# count   15465.000000  15465.000000  15465.000000  15465.000000  15465.000000
# mean   189298.588425     24.763272    181.093631     75.482703     63.948594
# std     39648.820272      4.624565      6.635182      6.907243      7.208610
# min         2.000000     16.000000    155.000000     50.000000     40.000000
# 25%    178043.000000     21.000000    176.000000     70.000000     59.000000
# 50%    200844.000000     24.000000    181.000000     75.000000     64.000000
# 75%    214326.000000     28.000000    186.000000     80.000000     69.000000
# max    225562.000000     44.000000    203.000000    110.000000     93.000000
#
#           potential  value_eur  wage_eur  international_reputation  \
# count  15465.000000    15465.0   15465.0              15465.000000
# mean      68.483091        0.0       0.0                  1.126350
# std        6.611708        0.0       0.0                  0.401362
# ...

# %%
# understanding df.describe()

# %%
# mean, std,min ,25,50,50,75, max

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15465 entries, 0 to 15464
# Columns: 104 entries, sofifa_id to rb
# dtypes: float64(17), int64(11), object(76)
# memory usage: 12.3+ MB

# %%
df.dtypes
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 104, dtype: object

# %% [markdown]
# # Exploring parameters of to_csv for writing

# %%
df1 = df.head(50)

# %%
df1
# Out:
#     sofifa_id                                         player_url  \
# 0      158023  https://sofifa.com/player/158023/lionel-messi/...
# 1       20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2        9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3       41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 5      176580  https://sofifa.com/player/176580/luis-suarez/1...
# 6      183277  https://sofifa.com/player/183277/eden-hazard/1...
# 7        7826  https://sofifa.com/player/7826/robin-van-persi...
# 8      121944  https://sofifa.com/player/121944/bastian-schwe...
# 9      156616  https://sofifa.com/player/156616/franck-ribery...
# 10     167397  https://sofifa.com/player/167397/radamel-falca...
# 11     173731  https://sofifa.com/player/173731/gareth-bale/1...
# 12     188545  https://sofifa.com/player/188545/robert-lewand...
# ...

# %%
df1.to_csv('dummy.csv',index=None,columns=['short_name','age'])

# %%
pd.read_csv('dummy.csv')
# Out:
#            short_name  age
# 0            L. Messi   27
# 1   Cristiano Ronaldo   29
# 2           A. Robben   30
# 3      Z. Ibrahimović   32
# 4            M. Neuer   28
# 5           L. Suárez   27
# 6           E. Hazard   23
# 7       R. van Persie   30
# 8   B. Schweinsteiger   29
# 9           F. Ribéry   31
# 10             Falcao   28
# 11            G. Bale   24
# 12     R. Lewandowski   25
# 13            P. Lahm   30
# 14       Sergio Ramos   28
# 15       Thiago Silva   29
# 16        David Silva   28
# 17          L. Modrić   28
# 18       J. Rodríguez   22
# 19             Neymar   22
# 20        T. Courtois   22
# 21         M. Hummels   25
# 22        A. Di María   26
# 23            M. Reus   25
# 24          T. Müller   24
# 25          S. Agüero   26
# 26            M. Özil   25
# 27               Xavi   34
# 28           Y. Touré   31
# 29          W. Rooney   28
# 30         V. Kompany   28
# 31           M. Götze   22
# 32    Sergio Busquets   25
# ...

# %% [markdown]
# # Accessing the columns

# %%
df.tail()
# Out:
#        sofifa_id                                         player_url  \
# 15460     220806  https://sofifa.com/player/220806/ellis-redman/...
# 15461     225509  https://sofifa.com/player/225509/aaron-collins...
# 15462     217591  https://sofifa.com/player/217591/piotr-zemlo/1...
# 15463     222947  https://sofifa.com/player/222947/tom-davies/15...
# 15464     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#        short_name      long_name  age         dob  height_cm  weight_kg  \
# 15460   E. Redman   Ellis Redman   17  1996-09-26        187         81
# 15461  A. Collins  Aaron Collins   17  1997-06-01        178         57
# 15462    P. Żemło    Piotr Żemło   18  1995-07-10        190         76
# 15463   T. Davies     Tom Davies   22  1992-04-18        180         70
# 15464  P. Tisdale   Paul Tisdale   41  1973-01-14        175         72
#
#       nationality            club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# ...

# %%
df['long_name']
# Out:
# 0             Lionel Andrés Messi Cuccittini
# 1        Cristiano Ronaldo dos Santos Aveiro
# 2                               Arjen Robben
# 3                         Zlatan Ibrahimović
# 4                               Manuel Neuer
#                         ...
# 15460                           Ellis Redman
# 15461                          Aaron Collins
# 15462                            Piotr Żemło
# 15463                             Tom Davies
# 15464                           Paul Tisdale
# Name: long_name, Length: 15465, dtype: object

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
type(df['long_name']) # one column is a series
# Out:
# pandas.core.series.Series

# %%
# converting to dataframe
df[['long_name']]
# Out:
#                                  long_name
# 0           Lionel Andrés Messi Cuccittini
# 1      Cristiano Ronaldo dos Santos Aveiro
# 2                             Arjen Robben
# 3                       Zlatan Ibrahimović
# 4                             Manuel Neuer
# ...                                    ...
# 15460                         Ellis Redman
# 15461                        Aaron Collins
# 15462                          Piotr Żemło
# 15463                           Tom Davies
# 15464                         Paul Tisdale
#
# [15465 rows x 1 columns]

# %%
type(df[['long_name']])
# Out:
# pandas.core.frame.DataFrame
