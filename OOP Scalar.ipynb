# %%
# Benefits of functional programming

# %%
# First class functions

# %%
# OOP is way of organising the code
# we use make use of both while making a program
# why OOP
# real world problem solving
# eg: banking problem | account, tx, customer, services
# eg: school | students, teacher
# creating  entity student1 ,student2, student3 | all will have same properties but values will be different
#  same for teachesrs and other entities

# %%
# what is a class
#  class is a template , a blueprint

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# creating  a student teamplate 
# it will have properties/characteristics/attributes
# its behaviour/tasks/methods | to change the state/value  of the property

# %% [markdown]
# # creating  a class

# %%
class Student: #creating  a class without any property or methods
    pass

# creating an instance of the class
# creating an object
# type of object is Student

s1 = Student()

# %%
s1

# %%
print(type(s1)) #we have created a class called Student , this is same as class str or int that is inbuilt
# Out:
# <class '__main__.Student'>

# %%
s2 = Student()

# %%
s2

# %%
# both s1 and s2 have diff address

# %%
# attributes of an object are the properties of the object
# s1 and s2 have same property/attribute
# but the value of the attribute are diffferent
s1.name = "rahul"
s2.name = "ramesh"

# %%
print(s1.name)
print(s2.name)
# Out:
# rahul
# ramesh

# %%
# but there is no point in creating attributes outside the class
# we are not sharing the common attributes of the  objetcts
# which we can provide values

# %% [markdown]
# # creating class with init

# %%
 class Student:
        def __init__(self):
            self.name = "placeholder"

# %%
s1 = Student()
s2 = Student()
# accessing a property with dot notation
s1.name
# Out:
# 'placeholder'

# %%
# changing value of the attribute
s1.name = "Rakesh"

# %%
s1.name
# Out:
# 'Rakesh'

# %%
s2.name #this value will not be updated as the object is different
# Out:
# 'placeholder'

# %%
# understanding the class
# __init__ = initialisation is like a constructor 
# self

# %%
 class Student:
        def __init__(self):
            print(self)
            self.name = "placeholder"
s1 = Student()
print(s1)

# %% [markdown]
# # other magic methods

# %%
# this will make the user feel in line with other functions

# %%
l1 = [11,2,23,2,5,8,7,4]
print(l1)
# Out:
# [11, 2, 23, 2, 5, 8, 7, 4]

# %%
 class Student:
        def __init__(self):
            self.name = "placeholder"
        def __str__(self):
            return "The name of Student is : {}".format(self.name)
s1 = Student()
print(s1)
# Out:
# The name of Student is : placeholder

# %%
# adding more parameters from outside

# %%
 class Student:
        def __init__(self,name,roll):
            self.name = name
            self.roll = roll
        def __str__(self):
            return "The name of Student is : {} and roll no {}".format(self.name , self.roll)
s1 = Student('Rahul',100)
print(s1)
# Out:
# The name of Student is : Rahul and roll no 100

# %% [markdown]
# # understanding the class variable/attribute

# %%
 class Student:
        def __init__(self,name):
            self.name = name
            counter = 0
            counter = counter+1
            self.roll = counter
        def __str__(self):
            return "The name of Student is : {} and roll no {}".format(self.name , self.roll)

# %%
s1 = Student('Rahul')
print(s1)
# Out:
# The name of Student is : Rahul and roll no 1

# %%
s1 = Student('Ramesh')
print(s1)
# Out:
# The name of Student is : Ramesh and roll no 1

# %%
# the counter will reset to 0 each time the object is created
# but will not be changed if the attibute belongs to the class

# %%
 class Student:
        counter = 0 #class variable
        def __init__(self,name):
            self.name = name            
            Student.counter = Student.counter+1 #sharing a class variable
            self.roll = Student.counter
        def __str__(self):
            return "The name of Student is : {} and roll no {}".format(self.name , self.roll)

# %%
s1 = Student('Rahul')
print(s1)
s2 = Student('Ramesh')
print(s2)
# Out:
# The name of Student is : Rahul and roll no 3
# The name of Student is : Ramesh and roll no 4

# %%
print(s1.counter) #check in local scope , but is not there , so it check in the class , and we have given the access 
print(s2.counter)
# Out:
# 4
# 4

# %%
print(Student.counter)
# Out:
# 4

# %%
print(s1.roll)# this is the value we set
print(s2.roll)
# Out:
# 3
# 4

# %% [markdown]
# # modifying  class variable

# %%
Student.counter = 555
print(s1.counter)
print(s2.counter)
# Out:
# 555
# 555

# %%
 class Student:
        counter = 100 #class variable
        def __init__(self,name):
            self.name = name            
            Student.counter = Student.counter+1 #sharing a class variable
            self.roll = Student.counter
        def __str__(self):
            return "The name of Student is : {} and roll no {}".format(self.name , self.roll)
s1 = Student('Rahul')
print(s1)
s2 = Student('Ramesh')
print(s2)
s3 = Student('Ramu')
print(s3)
# Out:
# The name of Student is : Rahul and roll no 101
# The name of Student is : Ramesh and roll no 102
# The name of Student is : Ramu and roll no 103

# %%
# changin the values
s1.counter = 777

# %%
print(s1.counter) # new object will be created s1.counter fr this object only , local attribute fo this obj only
print(s2.counter) #access the class variable
print(s3.counter)  #access the class variable
# Out:
# 777
# 103
# 103

# %%
# eg2

# %%
class Vehicle:
    country = "India"
    def __init__(self,name,mileage):
        self.name = name
        self.mileage = mileage
    def __str__(self):
        return 'Vehicle name : {} \nMileage : {}'.format(self.name,self.mileage)
    
v1 = Vehicle('Maruti',12)

# %%
print(v1)
# Out:
# Vehicle name : Maruti
# Mileage : 12

# %%
print(v1.country) #v1 has access to the class variable
# Out:
# India

# %%
v1.country = "USA" #separate variable willl be created for this v1
print(v1.country)
print(Vehicle.country)
# Out:
# USA
# India

# %%
# creating a normal function inside a class and call the function/method on the object

# %%
 class Student:
        counter = 100 #class variable
        def __init__(self,name):
            self.name = name            
            Student.counter = Student.counter+1 #sharing a class variable
            self.roll = Student.counter
        def __str__(self):
            return "The name of Student is : {} and roll no {}".format(self.name , self.roll)
        
        def intro(self):
            print("My name is {}".format(self.name))
s1 = Student('Rahul')
s1.intro()
# Out:
# My name is Rahul

# %%
class Account:
    counter = 0
    def __init__(self,opening_bal=0):
        Account.counter = Account.counter+1
        self.id = Account.counter
        self.bal = opening_bal
        
    def __str__(self):
        return "Acc Number:{},Acc bal : {}".format(self.id,self.bal)

# %%
a1 = Account(100)
a2 = Account()
print(a1)
print(a2)
# Out:
# Acc Number:1,Acc bal : 100
# Acc Number:2,Acc bal : 0

# %%
# adding more features
class Account:
    counter = 0
    def __init__(self,opening_bal=0):
        Account.counter = Account.counter+1
        self.id = Account.counter
        self.bal = opening_bal
        
    def __str__(self):
        return "Acc Number:{},Acc bal : {}".format(self.id,self.bal)
    
    def deposit(self,amount):
        if amount>0:
            self.bal = self.bal+amount
    def withdraw(self,amount):
        if amount>0 and self.bal >=amount:
            self.bal=self.bal-amount
            return True
        else:
            return False

# %%
a1 = Account(100)
a2 = Account()
a1.deposit(50)
a2.withdraw(300)#the bal will turn neg, need to add certain conditions
print(a1)
print(a2)
# Out:
# Acc Number:1,Acc bal : 150
# Acc Number:2,Acc bal : 0

# %% [markdown]
# # Inheritance

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Account:
    counter = 0
    def __init__(self,opening_bal=0):
        Account.counter = Account.counter+1
        self.id = Account.counter
        self.bal = opening_bal
        
    def __str__(self):
        return "Acc Number:{},Acc bal : {}".format(self.id,self.bal)
    
    def deposit(self,amount):
        if amount>0:
            self.bal = self.bal+amount
    def withdraw(self,amount):
        if amount>0 and self.bal >=amount:
            self.bal=self.bal-amount

# %%
class SavingsAccount(Account):
    pass

# %%
class CurrentAccount(Account):
    pass

# %%
s1 = SavingsAccount()
c1 = CurrentAccount()

# %%
print(s1)
print(c1)
# Out:
# Acc Number:1,Acc bal : 0
# Acc Number:2,Acc bal : 0

# %%
# adding more features
# limiting the number of TX to 5

class Account:
    counter = 0
    def __init__(self,opening_bal=0):
        Account.counter = Account.counter+1
        self.id = Account.counter
        self.bal = opening_bal
        self.num_transactions = 0
        self.max_transactions = 1
        
    def __str__(self):
        return "Acc Number:{},Acc bal : {} and num of Tx done{}".format(self.id,self.bal,self.num_transactions)
    
    def deposit(self,amount):
        if amount>=0 and self.num_transactions < self.max_transactions:
            self.bal = self.bal+amount
            self.num_transactions = self.num_transactions+1
    def withdraw(self,amount):
        if amount>0 and self.bal >=amount and self.num_transactions < self.max_transactions:
            self.bal=self.bal-amount
            self.num_transactions = self.num_transactions+1

# %%
s3 =Account()

# %%
s3.deposit(100)
print(s3)
# Out:
# Acc Number:2,Acc bal : 100 and num of Tx done1

# %%
s3.deposit(100)
print(s3)
# Out:
# Acc Number:2,Acc bal : 200 and num of Tx done2

# %%
s3.deposit(100)
print(s3)
# Out:
# Acc Number:2,Acc bal : 300 and num of Tx done3

# %%
s3.deposit(100)
print(s3)
# Out:
# Acc Number:2,Acc bal : 400 and num of Tx done4

# %%
s3.deposit(100)
print(s3)
# Out:
# Acc Number:2,Acc bal : 500 and num of Tx done5

# %%
s3.deposit(100)
print(s3)
# Out:
# Acc Number:2,Acc bal : 500 and num of Tx done5

# %%
# chnaging max tx limit for current acc to 100

# %%
class CurrentAccount(Account):
    def __init__(self):
        self.max_transactions = 100

# %%
# we wil get 'CurrentAccount' object has no attribute 'num_transactions' error
# since the child is trying to access but not getting the attribute ? is this the case ??
# instead we overwritten the parent __init__ and the new __init__ has no num_transactions
# thus we got the error

c1 = CurrentAccount()
c1.deposit(100)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [171], in <cell line: 2>()
#       1 c1 = CurrentAccount()
# ----> 2 c1.deposit(100)
#
# Input In [156], in Account.deposit(self, amount)
#      15 def deposit(self,amount):
# ---> 16     if amount>=0 and self.num_transactions < self.max_transactions:
#      17         self.bal = self.bal+amount
#      18         self.num_transactions = self.num_transactions+1
#
# AttributeError: 'CurrentAccount' object has no attribute 'num_transactions'

# %%
# how to solve this ?

# %%
class CurrentAccount(Account):
    def __init__(self):
        super().__init__() # call the parent __init__ 
        self.max_transactions = 3 # max_transactions value willl be update with this one

# %%
c1 = CurrentAccount()
c1.deposit(100)
print(c1)
# Out:
# Acc Number:1,Acc bal : 100 and num of Tx done1

# %%
c1.deposit(100)
print(c1)
# Out:
# Acc Number:1,Acc bal : 200 and num of Tx done2

# %%
c1.deposit(100)
print(c1)
# Out:
# Acc Number:1,Acc bal : 300 and num of Tx done3

# %%
c1.deposit(100)
print(c1)
# Out:
# Acc Number:1,Acc bal : 300 and num of Tx done3

# %%
s1 = SavingsAccount()
s1.deposit(500)
print(s1)
# Out:
# Acc Number:1,Acc bal : 500 and num of Tx done1

# %%
s1.deposit(500)
print(s1)
# Out:
# Acc Number:1,Acc bal : 500 and num of Tx done1

# %%
class CurrentAccount(Account):
    def __init__(self):
        print(super()) #checking whts in super()
        super().__init__() # call the parent __init__ 
        self.max_transactions = 3 # max_transactions value willl be update with this one

# %%
c5 =  CurrentAccount()
# Out:
# <super: <class 'CurrentAccount'>, <CurrentAccount object>>

# %%
#  chaking methods and attributes in a custom class
Account.__dict__
# Out:
# mappingproxy({'__module__': '__main__',
#               'counter': 2,
#               '__init__': <function __main__.Account.__init__(self, opening_bal=0)>,
#               '__str__': <function __main__.Account.__str__(self)>,
#               'deposit': <function __main__.Account.deposit(self, amount)>,
#               'withdraw': <function __main__.Account.withdraw(self, amount)>,
#               '__dict__': <attribute '__dict__' of 'Account' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Account' objects>,
#               '__doc__': None})

# %% [markdown]
# # Private variables

# %%
class Account:
    counter = 0
    def __init__(self,opening_bal=0):
        Account.counter = Account.counter+1
        self.id = Account.counter
        self.bal = opening_bal
        self.num_transactions = 0
        self.max_transactions = 1
        
    def __str__(self):
        return "Acc Number:{},Acc bal : {} and num of Tx done{}".format(self.id,self.bal,self.num_transactions)
    
    def deposit(self,amount):
        if amount>=0 and self.num_transactions < self.max_transactions:
            self.bal = self.bal+amount
            self.num_transactions = self.num_transactions+1
    def withdraw(self,amount):
        if amount>0 and self.bal >=amount and self.num_transactions < self.max_transactions:
            self.bal=self.bal-amount
            self.num_transactions = self.num_transactions+1
            
class SavingsAccount(Account):
    pass
class CurrentAccount(Account):
    def __init__(self):
        super().__init__() # call the parent __init__ 
        self.max_transactions = 3 # max_transactions value willl be update with this one

# %%
sa1 = SavingsAccount()
ca1 = CurrentAccount()

# %%
sa1.deposit(100)
print(sa1)
# Out:
# Acc Number:1,Acc bal : 100 and num of Tx done1

# %%
# we can change the value of attributes outside the class as well
# but this is not desired
# there should be a way to change the attribute through a method only
sa1.bal = 500
print(sa1)
# Out:
# Acc Number:1,Acc bal : 500 and num of Tx done1

# %%
# Public Access Modifier : easily accessible from any part of the program
# Protected Access Modifier : declared protected by adding a single underscore ‘_’
# Private Access Modifier : declared private by adding a double underscore ‘__’

# %%
class Account:
    counter = 0
    def __init__(self,opening_bal=0):
        Account.counter = Account.counter+1
        self.id = Account.counter
        self.__bal = opening_bal
        self.num_transactions = 0
        self.max_transactions = 5
        
    def __str__(self):
        return "Acc Number:{},Acc bal : {} and num of Tx done{}".format(self.id,self.__bal,self.num_transactions)
    
    def deposit(self,amount):
        if amount>=0 and self.num_transactions < self.max_transactions:
            self.__bal = self.__bal+amount
            self.num_transactions = self.num_transactions+1
    def withdraw(self,amount):
        if amount>0 and self.__bal >=amount and self.num_transactions < self.max_transactions:
            self.__bal=self.__bal-amount
            self.num_transactions = self.num_transactions+1
            
class SavingsAccount(Account):
    pass
class CurrentAccount(Account):
    def __init__(self):
        super().__init__() # call the parent __init__ 
        self.max_transactions = 3 # max_transactions value willl be update with this one
sa1 = SavingsAccount()
ca1 = CurrentAccount()

# %%
sa1.deposit(1000)
sa1.withdraw(100)
print(sa1)
# Out:
# Acc Number:1,Acc bal : 900 and num of Tx done2

# %%
sa1.withdraw(500)
print(sa1)
# Out:
# Acc Number:1,Acc bal : 400 and num of Tx done3

# %%
sa1.deposit(1000)
print(sa1)
# Out:
# Acc Number:1,Acc bal : 1400 and num of Tx done4

# %%
# trying to change the balance from outside 
sa1.__bal = 500 # new attribute will be created instead of changin the original ones
print(sa1)
# Out:
# Acc Number:1,Acc bal : 1400 and num of Tx done4

# %%
# name mangling
# sa1.__bal will be converted to _Account__bal

sa1._Account__bal
# Out:
# 1400

# %%
# we still can update the balance
sa1._Account__bal =5000
print(sa1)
# Out:
# Acc Number:1,Acc bal : 5000 and num of Tx done4

# %% [markdown]
# # Encapsulation

# %%
class PowerPlant:
    name  = "CSTP"

    def __init__(self, location,capacity, employees,):
        # self.location =  location # public
        self.__location =  location # private , sensitive info
        self.capacity = capacity
        self.employees = employees
        print(id(self.__location))

    # getter
    # accessor
    def locate(self):
        return self.__location

    #setter
    # modifier
    def locate_change(self,new):
         self.__location  = new
        #  return self.__location




p1 = PowerPlant("Nasik", '500MW' , 150)


print(p1.capacity)
print(p1.employees)
# print(p1.location) # this will give error

p1.__location = "tarapur" #this created a new atrribute 
print(p1.__location) # no attribute 

print(id(p1.__location))

p1.hello = "nagpur"
print(p1.hello)

# accessing a private variable 

# through method inside the class

print(p1.locate())

# through name mangling 

print(p1._PowerPlant__location)
print(id(p1._PowerPlant__location))


# changing  a private variable 

# through name mangling 

p1._PowerPlant__location = "Satara" #changing
print(p1.locate()) # accessing thr method
print(p1._PowerPlant__location) # acc through name mangling 



# through method inside the class


p1.locate_change("Chennai")
print(p1.locate())
print(id(p1._PowerPlant__location))
print(p1._PowerPlant__location)
# Out:
# 2784256850352
# 500MW
# 150
# tarapur
# 2784256839280
# nagpur
# Nasik
# Nasik
# 2784256850352
# Satara
# Satara
# Chennai
# 2784256737776
# Chennai

# %% [markdown]
# # polymorphism

# %%
# Polymorphism
    #Overriding
        # user defind method
        # inbulit method


    # Overloading
        # method
        # operator

# %%
class Account:
    counter = 0
    def __init__(self,opening_bal=0):
        Account.counter = Account.counter+1
        self.id = Account.counter
        self.__bal = opening_bal
        self.num_transactions = 0
        self.max_transactions = 5
        
    def __str__(self):
        return "Acc Number:{},Acc bal : {} and num of Tx done{}".format(self.id,self.__bal,self.num_transactions)
    
    def deposit(self,amount):
        if amount>=0 and self.num_transactions < self.max_transactions:
            self.__bal = self.__bal+amount
            self.num_transactions = self.num_transactions+1
    def withdraw(self,amount):
        if amount>0 and self.__bal >=amount and self.num_transactions < self.max_transactions:
            self.__bal=self.__bal-amount
            self.num_transactions = self.num_transactions+1
            
class SavingsAccount(Account):
    def get_interest(self):
        return self._Account__bal*0.07
class CurrentAccount(Account):
    def __init__(self):
        super().__init__() # call the parent __init__ 
        self.max_transactions = 3 # max_transactions value willl be update with this one
        
    def get_interest(self):
        return self._Account__bal*0
    
sa1 = SavingsAccount()
ca1 = CurrentAccount()

# %%
sa1.deposit(100)
ca1.deposit(100)

# %%
ca1.get_interest()
# Out:
# 0

# %%
sa1.get_interest()
# Out:
# 7.000000000000001

# %%
# eg2

# %%
# we need to write extra logic for overloading 
# over riding : same name 
class maths():
    def area(self,a,b=0):
        if b > 0:
            print(a*b)
        else:
            print(a*a)


m1 = maths()
m1.area(23,33)
m1.area(23)

# ex:
class Greet:
    def Hello(self,name=None):
        if name is not None:
            print("Hello "+ name)
        else:
            print("Hello")

g1 =  Greet()
g1.Hello()
g1.Hello("Sanket")
# Out:
# 759
# 529
# Hello
# Hello Sanket

# %%
# method overloading using magic methods


#Example
class Person:
    def __init__(self,fn,ln):
        self.fn = fn
        self.ln = ln

    # def show_name(self):
    #     print("{} {}".format(self.fn ,self.ln))

    def __str__(self):
        return "{} {}".format(self.fn ,self.ln)
    
p1 = Person("Vikas" ,"Jain")
x = "Ramesh"
print(x)

# p1.show_name()
print(p1)
# Out:
# Ramesh
# Vikas Jain

# %%
#Overriding
    # user defind method

class India:
    def capital(self):
        print("New delhi")

class Nepal:
    def capital(self):
        print("kathmandu")

class SriLanka:
    def capital(self):
        print("Colombo")


ind = India()
nep = Nepal()
sl = SriLanka()


ind.capital()
nep.capital()
sl.capital()
# Out:
# New delhi
# kathmandu
# Colombo
